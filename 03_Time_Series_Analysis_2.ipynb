# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush1856/time-series-and-recommendation-system/blob/main/03_Time_Series_Analysis_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 03.Time Series Analysis - 2

# %% [markdown]
# ### SES

# %%
model = sm.tsa.ExponentialSmoothing(mobile_sales.Sales).fit(smoothing_level = 0.5)
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model.fittedvalues.plot(label='fitted')
mobile_sales.Sales.plot(label='original')
plt.legend()

# %%
pred = model.forecast(steps = 12)
mobile_sales.Sales.tail(100).plot(style='-o', label='actual')
pred.plot(style='-o', label='predicted')
plt.legend()

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales).fit(smoothing_level=1/(2*12))
test_x['pred'] = model.forecast(steps = 12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# MAE : 1703.418
# RMSE : 1980.77
# MAPE: 0.113

# %% [markdown]
# ### DES

# %%
model = sm.tsa.ExponentialSmoothing(mobile_sales.Sales, trend="add").fit(smoothing_level = 0.5)
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
model.fittedvalues.plot(label='fitted')
mobile_sales.Sales.plot(label='original')
plt.legend()

# %%
pred = model.forecast(steps = 12)
mobile_sales.Sales.tail(100).plot(style='-o', label='actual')
pred.plot(style='-o', label='predicted')
plt.legend()

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='add').fit(smoothing_level=1/(2*12))
test_x['pred'] = model.forecast(steps = 12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE : 1275.319
# RMSE : 1498.624
# MAPE: 0.089

# %% [markdown]
# ### TES

# %%
model = sm.tsa.ExponentialSmoothing(mobile_sales.Sales, trend="add", seasonal="add").fit(smoothing_level = 0.5)
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
model.fittedvalues.plot(label='fitted')
mobile_sales.Sales.plot(label='original')
plt.legend()

# %%
pred = model.forecast(steps = 12)
mobile_sales.Sales.tail(100).plot(style='-o')
pred.plot(style='-o')
# Out:
# <Axes: xlabel='DATE'>

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='add', seasonal='add').fit(smoothing_level=0.05)
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# MAE : 770.762
# RMSE : 826.025
# MAPE: 0.052

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='mul', seasonal='add').fit(smoothing_level=0.05)
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:84: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE : 1.9701487496153411e+24
# RMSE : 2.4003106240368202e+24
# MAPE: 1.3604178904641883e+20

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='add', seasonal='mul').fit(smoothing_level=0.05)
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE : 558.427
# RMSE : 612.526
# MAPE: 0.038

# %%
model = sm.tsa.ExponentialSmoothing(train_x.Sales, trend='mul', seasonal='mul').fit(smoothing_level=0.05)
test_x['pred'] = model.forecast(steps=12)
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# MAE : 471.023
# RMSE : 538.085
# MAPE: 0.032

# %% [markdown]
# ### ADF Test

# %%
sm.tsa.stattools.adfuller(mobile_sales.Sales)[1]
# Out:
# 0.9451861677902991

# %%
def adf_test(dataset):
   pvalue = sm.tsa.stattools.adfuller(dataset)[1]
   if pvalue <= 0.05:
      print('Sequence is stationary')
   else:
      print('Sequence is not stationary')

adf_test(mobile_sales.Sales)
# Out:
# Sequence is not stationary

# %%
detrend = mobile_sales.Sales.diff()
detrend.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
adf_test(detrend.dropna())
# Out:
# Sequence is stationary

# %%
deseas = mobile_sales.Sales.diff(12)
deseas.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
stationary = mobile_sales.Sales.diff(1).diff(12)
stationary.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(mobile_sales.Sales);

# %%
plot_acf(mobile_sales.Sales.diff().dropna());

# %%
plot_pacf(mobile_sales.Sales);
